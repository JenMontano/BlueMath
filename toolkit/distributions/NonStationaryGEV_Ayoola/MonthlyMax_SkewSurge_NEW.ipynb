# %% [markdown]
# # Notebook to analize Non-Stationary GEV for Monthly Maxima

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
from bluemath_tk.distributions.nonstat_gev import NonStatGEV

# %% [markdown]
# ## Load Skew Surge and SOI data

# %%
data_path = "inputs/station_40390_SanFrancisco.parquet"
data = pd.read_parquet(f"{data_path}")
data.drop_duplicates(subset=["surge_time"], inplace=True)
data.set_index("surge_time", inplace=True)
data.index = pd.to_datetime(data.index)
data["year"] = data.index.year
data["month"] = data.index.month
data["day"] = data.index.day
data["hour"] = data.index.hour
data["minute"] = data.index.minute
data["second"] = data.index.second
data
# Out:
#                      skew_surge  year  month  day  hour  minute  second
# surge_time
# 1950-01-01 00:00:00       0.277  1950      1    1     0       0       0
# 1950-01-01 08:20:00       0.110  1950      1    1     8      20       0
# 1950-01-01 21:40:00       0.277  1950      1    1    21      40       0
# 1950-01-03 03:00:00       0.065  1950      1    3     3       0       0
# 1950-01-03 09:40:00       0.155  1950      1    3     9      40       0
# ...                         ...   ...    ...  ...   ...     ...     ...
# 2024-12-30 03:00:00       0.501  2024     12   30     3       0       0
# 2024-12-30 11:10:00       0.506  2024     12   30    11      10       0
# 2024-12-30 23:40:00       0.254  2024     12   30    23      40       0
# 2024-12-31 17:30:00       0.365  2024     12   31    17      30       0
# 2024-12-31 23:40:00       0.318  2024     12   31    23      40       0
#
# [55109 rows x 7 columns]

# %%
data_monthly_maxima_idxs = data.resample("M")["skew_surge"].idxmax()
data_monthly_maxima = data.loc[data_monthly_maxima_idxs]
data_monthly_maxima
# Out:
# /tmp/ipykernel_4079886/3831735457.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_monthly_maxima_idxs = data.resample("M")["skew_surge"].idxmax()
#                      skew_surge  year  month  day  hour  minute  second
# surge_time
# 1950-01-19 22:30:00       0.313  1950      1   19    22      30       0
# 1950-02-24 05:30:00       0.445  1950      2   24     5      30       0
# 1950-03-05 09:50:00       0.444  1950      3    5     9      50       0
# 1950-04-15 01:20:00       0.452  1950      4   15     1      20       0
# 1950-05-31 15:00:00       0.355  1950      5   31    15       0       0
# ...                         ...   ...    ...  ...   ...     ...     ...
# 2024-08-25 20:10:00       0.305  2024      8   25    20      10       0
# 2024-09-29 04:40:00       0.360  2024      9   29     4      40       0
# 2024-10-23 06:10:00       0.342  2024     10   23     6      10       0
# 2024-11-21 05:50:00       0.678  2024     11   21     5      50       0
# 2024-12-21 13:30:00       0.526  2024     12   21    13      30       0
#
# [900 rows x 7 columns]

# %%
data_monthly_maxima.skew_surge.plot()
# Out:
# <Axes: xlabel='surge_time'>

# %%
days_in_month = {
    1: 31,
    2: 28.25,
    3: 31,
    4: 30,
    5: 31,
    6: 30,
    7: 31,
    8: 31,
    9: 30,
    10: 31,
    11: 30,
    12: 31,
}
data_monthly_maxima["time"] = (
    data_monthly_maxima["year"]
    - np.min(data_monthly_maxima["year"])
    + (data_monthly_maxima["month"] - 1) / 12
    + data_monthly_maxima["day"] / data_monthly_maxima["month"].map(days_in_month) / 12
)
data_monthly_maxima
# Out:
#                      skew_surge  year  month  day  hour  minute  second  \
# surge_time
# 1950-01-19 22:30:00       0.313  1950      1   19    22      30       0
# 1950-02-24 05:30:00       0.445  1950      2   24     5      30       0
# 1950-03-05 09:50:00       0.444  1950      3    5     9      50       0
# 1950-04-15 01:20:00       0.452  1950      4   15     1      20       0
# 1950-05-31 15:00:00       0.355  1950      5   31    15       0       0
# ...                         ...   ...    ...  ...   ...     ...     ...
# 2024-08-25 20:10:00       0.305  2024      8   25    20      10       0
# 2024-09-29 04:40:00       0.360  2024      9   29     4      40       0
# 2024-10-23 06:10:00       0.342  2024     10   23     6      10       0
# 2024-11-21 05:50:00       0.678  2024     11   21     5      50       0
# 2024-12-21 13:30:00       0.526  2024     12   21    13      30       0
#
#                           time
# surge_time
# 1950-01-19 22:30:00   0.051075
# 1950-02-24 05:30:00   0.154130
# 1950-03-05 09:50:00   0.180108
# 1950-04-15 01:20:00   0.291667
# 1950-05-31 15:00:00   0.416667
# ...                        ...
# 2024-08-25 20:10:00  74.650538
# 2024-09-29 04:40:00  74.747222
# 2024-10-23 06:10:00  74.811828
# 2024-11-21 05:50:00  74.891667
# 2024-12-21 13:30:00  74.973118
#
# [900 rows x 8 columns]

# %%
soi_index_df = pd.read_csv(
    "https://crudata.uea.ac.uk/cru/data/soi/soi.dat",
    sep=r"\s+",
    engine="python",
    names=[
        "jan",
        "feb",
        "mar",
        "apr",
        "may",
        "jun",
        "jul",
        "aug",
        "sep",
        "oct",
        "nov",
        "dec",
        "annual",
    ],
)
# Construct a monthly index
soi_index_list = []
for year in range(1950, 2025):
    soi_index_list += list(soi_index_df.loc[year].values[:12])
soi_index = {"SOI": np.array(soi_index_list)}
soi_index
# Out:
# {'SOI': array([ 0.54,  1.58,  1.79,  1.67,  0.55,  3.06,  2.14,  1.14,  0.63,
#          1.68,  0.89,  2.46,  1.32,  0.47, -0.71, -1.03, -1.29, -0.52,
#         -1.33, -0.75, -1.17, -1.44, -0.98, -0.9 , -0.92, -0.83, -0.02,
#         -0.73,  0.67,  0.78,  0.51, -0.38, -0.24,  0.12, -0.22, -1.4 ,
#          0.12, -0.72, -0.79, -0.18, -2.72, -0.47, -0.06, -1.89, -1.35,
#         -0.18, -0.36, -0.61,  0.57, -0.52, -0.31,  0.41,  0.15, -0.49,
#          0.36,  0.9 ,  0.17,  0.09,  0.16,  1.31, -0.68,  1.3 ,  0.13,
#         -0.81,  0.88,  1.63,  1.8 ,  1.38,  1.4 ,  1.51,  1.38,  0.91,
#          1.16,  1.1 ,  0.89,  1.06,  1.44,  1.26,  1.19,  1.05,  0.06,
#          1.92,  0.11,  0.99,  0.43, -0.36, -0.37,  0.05, -1.18, -0.37,
#          0.18, -1.08, -1.01, -0.09, -1.23, -0.44, -1.89, -0.78, -0.32,
# %%
autogev_hs2 = NonStatGEV(
    xt=data_monthly_maxima["skew_surge"].values,
    t=data_monthly_maxima["time"].values,
    covariates=pd.DataFrame(soi_index),
    trends=False,
    var_name="skew_surge",
)

# Fit the GEV model
fit_results = autogev_hs2.auto_adjust()
fit_results
# Out:
# Starting Harmonic iterative process
# Iteration:  0 - AIC:  -258.7068659460886
# Iteration:  1 - AIC:  -372.591267579239
# Iteration:  2 - AIC:  -499.3869061023604
# Iteration:  3 - AIC:  -501.50089044323295
# Iteration:  4 - AIC:  -509.3708082873777
# Iteration:  5 - AIC:  -510.1902150753758
# Iteration:  6 - AIC:  -508.4759948861629
# End of the Harmonic iterative process
# Harmonic AIC: -510.1902150753758
#
# Starting Covariates iterative process
# Iteration:  7 - AIC:  -508.43251876224053
# End of Covariates iterative process
# Covariates AIC: -510.1902150753758
# {'x': array([ 0.32079543,  0.0813045 , -0.05726155,  0.0241457 ,  0.01808351,
#         -1.78078006,  0.41597886,  0.00241755, -0.1731961 ,  0.05437744,
#          0.02090316, -0.04867925,  0.03455631]),
#  'negloglikelihood': -268.09510753903487,
#  'success': True,
#  'message': '`gtol` termination condition is satisfied.',
#  'grad': array([ 1.27338130e-07,  6.28992922e-08,  9.62217831e-07, -1.92589490e-07,
#         -9.92700075e-07, -3.30829337e-08, -9.33397936e-08,  6.79475001e-07,
#         -4.82919550e-05,  5.48515095e-05,  2.90084165e-05,  4.20488761e-06,
#         -5.42711154e-06]),
#  'hess_inv': None,
#  'lambdas': [array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          -4.84050338e-05,  5.47082818e-05,  2.88311655e-05,  3.92076824e-06,
#          -5.17863628e-06])],
#  'beta0': 0.320795433905588,
#  'beta': array([ 0.0813045 , -0.05726155,  0.0241457 ,  0.01808351]),
#  'betaT': array([], dtype=float64),
#  'beta_cov': array([], dtype=float64),
#  'alpha0': -1.7807800620081369,
#  'alpha': array([0.41597886, 0.00241755]),
#  'alphaT': array([], dtype=float64),
#  'alpha_cov': array([], dtype=float64),
#  'gamma0': -0.17319610237084282,
#  'gamma': array([ 0.05437744,  0.02090316, -0.04867925,  0.03455631]),
#  'gammaT': array([], dtype=float64),
#  'gamma_cov': array([], dtype=float64),
#  'n_params': 13,
#  'AIC': -510.19021507806974,
#  'loglikelihood': 268.09510753903487,
#  'hessian': array([[-3.62415077e+04,  1.45391617e+04,  4.12899041e+02,
#          -4.58235845e+03, -4.26880421e+02, -4.75037175e+02,
#           7.48347859e+02,  1.09916909e+02, -3.94603831e+03,
#           1.41383247e+03,  2.40827088e+02, -6.97991999e+02,
#          -1.35381851e+02],
#         [ 1.45391617e+04, -2.04119331e+04, -2.13440211e+02,
#           8.41706693e+03, -2.53237446e+01,  7.48347859e+02,
#          -5.85297575e+02,  1.31724482e+02,  1.41383247e+03,
#          -2.32201515e+03, -6.76909257e+01,  1.19893540e+03,
#          -4.14459242e+01],
#          -2.84655844e-05, -1.81008170e-05, -2.67985333e-05,
#          -5.61292937e-04,  4.11266487e-05,  1.10380417e-04,
#           9.87727160e-04, -2.19803634e-05,  2.25834774e-04,
#           4.58449870e-05],
#         [-1.19018685e-05, -1.25205792e-05, -9.03455947e-05,
#          -2.50454507e-08, -2.10768907e-05, -4.05658256e-05,
#           2.54009365e-05, -4.21974137e-04,  1.22984485e-04,
#          -2.19803634e-05,  8.07312797e-04, -1.45083060e-04,
#          -5.67292772e-05],
#         [-8.68472803e-06, -2.18423385e-05,  6.53942287e-06,
#          -7.03977584e-05,  4.60966831e-06, -5.38010837e-05,
#          -1.02709511e-05,  3.19468321e-05,  5.01023284e-05,
#           2.25834774e-04, -1.45083060e-04,  6.22564264e-04,
#          -4.44428605e-05],
#         [-6.09162509e-06, -8.40027121e-06, -1.27769498e-05,
#           6.96338699e-06, -7.66780715e-05,  2.40470970e-05,
#          -2.93543184e-05, -2.79940712e-05,  8.03086041e-06,
#           4.58449870e-05, -5.67292772e-05, -4.44428605e-05,
#           7.99244150e-04]]),
#  'std_param': array([0.00672885, 0.00975255, 0.00921071, 0.00857675, 0.00877997,
#         0.0258021 , 0.03687358, 0.03606417, 0.02077432, 0.03142813,
#         0.02841325, 0.02495124, 0.02827091])}

# %%
autogev_hs2.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 autogev_hs2.plot()
#
# File ~/GitHub-GeoOcean/BlueMath_tk/bluemath_tk/distributions/nonstat_gev.py:5217, in NonStatGEV.plot(self, return_plot)
#    5209 #### Return periods
#    5210 if (
#    5211     self.ntrend_loc == 0
#    5212     and self.ntrend_sc == 0
#    (...)
#    5215     and self.nind_sh == 0
#    5216 ) and return_plot:
# -> 5217     self.ReturnPeriodPlot()
#
# File ~/GitHub-GeoOcean/BlueMath_tk/bluemath_tk/distributions/nonstat_gev.py:6024, in NonStatGEV.ReturnPeriodPlot(self, annualplot)
#    6022 for i in range(12):
#    6023     for j in range(nts):
# -> 6024         quanaggr[i, j] = self._aggquantile(1 - 1 / Ts[j], i / 12, (i + 1) / 12)[
#    6025             0
#    6026         ]
#    6027         stdQuan = self._ConfidInterQuanAggregate(
#    6028             1 - 1 / Ts[j], i / 12, (i + 1) / 12
#    6029         )
#    6030         stdDqX[i, j] = stdQuan * norm.ppf(
#    6031             1 - (1 - self.quanval) / 2, loc=0, scale=1
#    6032         )
#
# File ~/GitHub-GeoOcean/BlueMath_tk/bluemath_tk/distributions/nonstat_gev.py:6181, in NonStatGEV._aggquantile(self, q, t0, t1, beta0, beta, alpha0, alpha, gamma0, gamma, betaT, alphaT, gammaT, beta_cov, alpha_cov, gamma_cov)
#    6179 cov_locint = np.zeros(len(beta_cov))
#    6180 cov_scint = np.zeros(len(alpha_cov))
# -> 6181 cov_shint = np.zeros(len(gamma_cov))
#    6182 if len(pos) > 0:
#    6183     for i in range(len(beta_cov)):
#
# TypeError: object of type 'NoneType' has no len()
